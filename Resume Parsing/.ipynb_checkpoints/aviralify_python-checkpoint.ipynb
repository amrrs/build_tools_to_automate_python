# %%
import requests
from bs4 import BeautifulSoup
import markovify

# %%
# !! pip3 install markovify
# Out:
# ['Collecting markovify',
#  '  Downloading https://files.pythonhosted.org/packages/94/b2/b4ce1e461bb3482b1fd63328a2097aed5917cdfa0dbfe9492a84ea46e2ab/markovify-0.7.1.tar.gz',
#  'Requirement already satisfied: unidecode in /Users/abdrs/Library/Python/3.7/lib/python/site-packages (from markovify) (1.0.22)',
#  'Building wheels for collected packages: markovify',
#  '  Building wheel for markovify (setup.py): started',
#  "  Building wheel for markovify (setup.py): finished with status 'done'",
#  '  Stored in directory: /Users/abdrs/Library/Caches/pip/wheels/66/fe/5b/07257dd2401d9835447a0f0223f967c998c153404d32612253',
#  'Successfully built markovify',
#  'Installing collected packages: markovify',
#  'Successfully installed markovify-0.7.1']

# %%
url = "http://eepurl.com/guWmdf"

# %%
content = requests.get(url)

# %%
content.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\n<!doctype html>\n<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"> <head>\n        \n<meta property="og:title" content="Inside No Broker\'s Quest to Disrupt Housing | AJVC #83">\n<meta property="fb:page_id" content="43929265776">\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n<meta name="referrer" content="origin">        \n    \t<!-- NAME: VIGNELLI -->\n        <!--[if gte mso 15]>\n\t\t<xml>\n\t\t\t<o:OfficeDocumentSettings>\n\t\t\t<o:AllowPNG/>\n\t\t\t<o:PixelsPerInch>96</o:PixelsPerInch>\n\t\t\t</o:OfficeDocumentSettings>\n\t\t</xml>\n\t\t<![endif]-->\n\t\t<meta charset="UTF-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<title>Inside No Broker&#039;s Quest to Disrupt Housing | AJVC #83</title>\n        \n
# ...

# %%
import urllib.request    
urllib.request.urlretrieve(url, "test.txt")
# Out:
# ('test.txt', <http.client.HTTPMessage at 0x109c1a278>)

# %%
# !! ls
# Out:
# ['Untitled.ipynb',
#  '__pycache__',
#  'csv',
#  'output',
#  'pdf2txt.py',
#  'resume_parsing.ipynb',
#  'resumes',
#  'test.txt']
